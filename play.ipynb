# %% [markdown]
# # Playground for the AutoGrad

# %%
from autograd import DataPoint

# Creating a datapoint 
a = DataPoint(data=2)
a
# Out:
# DataPoint(data = 2)

# %%
# Adding two data points
b = DataPoint(data=3)

# Adding return another datapoint 
a + b
# Out:
# DataPoint(data = 5)

# %%
# Multiply
a * b
# Out:
# DataPoint(data = 6)

# %%
# Combining
a = DataPoint(data=2, _label='a')
b = DataPoint(data=3, _label='b')
c = DataPoint(data=3, _label='c')

e = a*b
e._label='e'

d = e + c
d._label='d'

f = DataPoint(data=-2, _label='f')
L = d * f
L._label='L'

# %%
# Plot the expression 
from autograd import graph_datapoint
graph_datapoint(L)
